# %%
library(ChAI) ## from here: https://github.com/aifimmunology/ChAi
## devtools::load_all('ChAI') ## Load in the latest version. You can also use devtools::install('ChAI') to install it locally
library(MOCHA)
library(SummarizedExperiment)
library(TxDb.Hsapiens.UCSC.hg38.refGene)
library(org.Hs.eg.db) 
library(dplyr)
# Out:
# Attaching package: ‘MOCHA’
#
#
# The following objects are masked from ‘package:ChAI’:
#
#     bulkDimReduction, bulkUMAP, getModelValues, renameCellTypes
#
#
# Warning message:
# “package ‘SummarizedExperiment’ was built under R version 4.4.2”
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
# Warning message:
# “package ‘matrixStats’ was built under R version 4.4.3”
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
# ...

# %%
library(ggplot2)
library(dplyr)
library(viridis)
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 4.4.3”
# Loading required package: viridisLite

# %%
images.path <- ""

# %%
anovaEnrichments <- read.csv('/home/workspace/Run_Metatype_threshold/Meta_EnrichedMotifs_ChromVAR_ANOVA.csv')

# %%
rnaSE <- readRDS('/home/workspace/ChAI_PseudobulkRNA_Meta_Annotated.rds')
exprGenes = thresholdGenes(rnaSE,
                           cellPopulation = 'all', 
                           detectionThreshold = 0.001, 
                           expressionThreshold = 2,
                           cellCountThreshold = 20)
lengths(exprGenes)
# Out:
#  ASC3  ASC4  ASC5  ASC2  ASC1
# 15812 15797 14216 13828  4005

# %%
anovaEnrichments$cell_type <- gsub(" effect", "", anovaEnrichments$contrast)

# %%
anovaEnrichments$statistic <- -log10(anovaEnrichments$p_adj) * anovaEnrichments$estimate

# %%
expressedEnrichments <- anovaEnrichments

# %%
for(i in names(exprGenes)){

    expressedEnrichments = dplyr::filter(expressedEnrichments, 
                              (motif %in% exprGenes[[i]] & cell_type == i) |
                              cell_type != i)

}
table(expressedEnrichments$cell_type)
# Out:
# ASC1 ASC2 ASC3 ASC4 ASC5
#  113  417  492  493  439

# %%
anovaEnrichments <- anovaEnrichments %>%
  rowwise() %>%
  mutate(is_expressed = motif %in% exprGenes[[cell_type]]) %>%
  ungroup()

# %%
table(anovaEnrichments$is_expressed, anovaEnrichments$cell_type)
# Out:
#
#         ASC1 ASC2 ASC3 ASC4 ASC5
#   FALSE  757  453  378  377  431
#   TRUE   113  417  492  493  439

# %%
write.csv(anovaEnrichments, 'anovaEnrichments.csv')

# %%
sig_up_motifs <- expressedEnrichments %>%
                    filter(p_adj < 0.1) %>%
                    filter(estimate > 0)

# %%
temp <- as.data.frame(table(sig_up_motifs$cell_type))
colnames(temp) <- c('cluster', 'value')
temp
# Out:
#   cluster value
# 1 ASC1     26
# 2 ASC2     85
# 3 ASC3    224
# 4 ASC4    244
# 5 ASC5    203

# %%
metas <- paste0("ASC", 1:5)
meta.palette <- c("#1C7987", "#7286AC", "#7A3859", "#99C2A2", "#F0A7A0") %>%
  setNames(metas)

# %%
ggplot(temp, aes(cluster, value, fill = cluster)) +
  geom_col() +  # Draw bars
  theme_linedraw() +  # Clean black-and-white theme
  scale_fill_manual(values = meta.palette) +  # Apply custom colors
  labs(x = NULL, y = "# of Enriched Motifs") +  # Label y-axis only
  theme(
    legend.position = "none",  # Hide legend for simplicity
    panel.grid.major.x = element_blank(),  # Remove vertical gridlines
    axis.text.x = element_text(hjust = 1, angle = 45)  # Tilt x-axis labels
  )
# Out:
# plot without title

# %%
ggsave(paste0(images.path, "bars_motifs_meta.png"), width = 2.6, height = 3)

# %%
top20 <- expressedEnrichments %>%
  filter(p_adj < 0.1) %>%
  filter(estimate > 0) %>%
  group_by(cell_type) %>%
  slice_max(order_by = estimate, n = 20, with_ties = FALSE) %>%
  ungroup()

# %%
table(top20$cell_type)
# Out:
# ASC1 ASC2 ASC3 ASC4 ASC5
#   20   20   20   20   20

# %%
selected_TFs <- unique(top20$motif)
length(selected_TFs)
# Out:
# [1] 67

# %%
anovaEnrichments <- anovaEnrichments %>%
  left_join(
    top20 %>%
      select(cell_type, motif) %>%
      mutate(is_top20 = TRUE),
    by = c("cell_type", "motif")
  ) %>%
  mutate(is_top20 = coalesce(is_top20, FALSE))

# %%
table(anovaEnrichments$is_top20)
# Out:
# FALSE  TRUE
#  4250   100

# %%
filtered_motifs <- anovaEnrichments %>% 
    filter(motif %in% selected_TFs) %>%
    mutate(motif = factor(motif, levels = selected_TFs))

# %%
table(filtered_motifs$cell_type)
# Out:
# ASC1 ASC2 ASC3 ASC4 ASC5
#   67   67   67   67   67

# %%
summary(filtered_motifs$estimate)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -38.8332  -6.5616   0.2852   0.0000   8.0857  23.9838

# %%
inf <- viridis(256, option = "inferno")

# %%
ggplot(filtered_motifs, aes(cell_type, motif, 
                            fill = estimate, 
                            size = mlogadjpval, 
                            color = p_adj < 0.1 & estimate > 0)) +
  geom_point(shape = 21, stroke = 1.2) +
  # geom_point(
  #   data = subset(filtered_motifs, is_top20),
  #   aes(shape="top 20"),
  #   shape = 21,
  #   stroke = 0.5,
  #   color = "black",
  #   fill = NA
  # ) +
  theme_bw() +
  scale_fill_gradientn(
      colours = c(inf[40], "white", inf[220]),
      values  = scales::rescale(c(-38.8332, 0, 23.9838 )),
    ) + 
  scale_color_manual(values = c("white", "grey50")) +
  scale_shape_manual(
    name = "Top 20 motif",
    values = 21
  ) +
  scale_size_area(max_size = 5) +
  scale_x_discrete(limits = rev) +
  theme(
    panel.grid = element_blank(),
    axis.text.x = element_text(hjust = 1, angle = 45),
    legend.position = "bottom",
    legend.box = "horizontal",
    legend.key.width = unit(1, "cm"),
    legend.key.height = unit(1, "cm"),
    legend.text.align = 0.5
  ) +
  labs(
    x = NULL, y = NULL,
    size = "mlogadjpval",
    color = "p_adj < 0.1 & estimate > 0",
    fill = "estimate"
  ) +
  guides(
      size = guide_legend(
        title.position = 'top',
        label.position = 'top',
        override.aes = list(
          shape = 21,
          fill  = "grey50",
          color = "grey50",
          stroke = 0
        )
      ), 
      color = guide_legend(
          title.position = 'top',
          label.position = 'top'
      ),
    ) +
  coord_flip()
# Out:
# plot without title

# %%
ggsave(paste0("bubble_motif_enrichment_estimate_no_top20.png"), width = 12, height = 3)

# %%
# we want to plot actual z score instead of just estimate value now
chrom <- readRDS('/home/workspace/Run_Metatype_threshold/ChAI_ChromVAR_scores_Meta.rds')

# %%
chrom
# Out:
# $Z_Score
# class: SummarizedExperiment
# dim: 870 6
# metadata(2): summarizedData History
# assays(5): ASC4 ASC1 ASC3 ASC5 ASC2
# rownames(870): TFAP2B TFAP2D ... TBX18 TBX22
# rowData names(0):
# colnames(6): EXP-00776-P1_BMC05967-001 EXP-00776-P1_SP05965-01 ...
#   EXP-00776-P1_SP06133-01 EXP-00776-P1_SP06134-01
# colData names(5): Sample pool_id chip_id batch_id PassQC
#
# $Deviations
# class: SummarizedExperiment
# dim: 870 6
# metadata(2): summarizedData History
# assays(5): ASC4 ASC1 ASC3 ASC5 ASC2
# rownames(870): TFAP2B TFAP2D ... TBX18 TBX22
# rowData names(0):
# colnames(6): EXP-00776-P1_BMC05967-001 EXP-00776-P1_SP05965-01 ...
#   EXP-00776-P1_SP06133-01 EXP-00776-P1_SP06134-01
# colData names(5): Sample pool_id chip_id batch_id PassQC

# %%
d <- chrom$Deviations

# %%
d
# Out:
# class: SummarizedExperiment
# dim: 870 6
# metadata(2): summarizedData History
# assays(5): ASC4 ASC1 ASC3 ASC5 ASC2
# rownames(870): TFAP2B TFAP2D ... TBX18 TBX22
# rowData names(0):
# colnames(6): EXP-00776-P1_BMC05967-001 EXP-00776-P1_SP05965-01 ...
#   EXP-00776-P1_SP06133-01 EXP-00776-P1_SP06134-01
# colData names(5): Sample pool_id chip_id batch_id PassQC

# %%
summary(assays(d)[[1]][9,])
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# 0.003790 0.005674 0.007566 0.008483 0.011136 0.014609

# %%
median(assays(z)[[1]])
# Out:
# [1] 1.424462

# %%
assays(z)[[1]]
# Out:
#           EXP-00776-P1_BMC05967-001 EXP-00776-P1_SP05965-01
# TFAP2B     2.10028556                2.0288467
# TFAP2D    -1.18175903                1.1999252
# TFAP2C     2.79837859                0.6678036
# TFAP2E    -0.02247123               -1.1783252
# TFAP2A     0.47364411                1.0723195
# ARID3A    -3.69171835                3.2662306
# ARID5B    -1.80144381               -2.6177933
# ARID3B     1.73964543                4.2482098
# ARID5A     1.16908459                2.0265649
# ARID3C    -2.29183918                1.4990817
# ARID2      3.87307674                1.0136245
# HMGA1     -4.67127701                0.8462651
# HMGA2     -0.32959941                2.3837482
# MAX        6.74627413                7.4212492
# MLXIPL     5.10643361                5.5866848
# ARNTL2     7.14858910                7.1426068
# AHRR      -1.77716045               -0.7693568
# TFE3       7.28782250                6.9832874
# HES2       3.19267469                3.2788036
# ...

# %%
chrom
# Out:
# $Z_Score
# class: SummarizedExperiment
# dim: 870 6
# metadata(2): summarizedData History
# assays(5): ASC4 ASC1 ASC3 ASC5 ASC2
# rownames(870): TFAP2B TFAP2D ... TBX18 TBX22
# rowData names(0):
# colnames(6): EXP-00776-P1_BMC05967-001 EXP-00776-P1_SP05965-01 ...
#   EXP-00776-P1_SP06133-01 EXP-00776-P1_SP06134-01
# colData names(5): Sample pool_id chip_id batch_id PassQC
#
# $Deviations
# class: SummarizedExperiment
# dim: 870 6
# metadata(2): summarizedData History
# assays(5): ASC4 ASC1 ASC3 ASC5 ASC2
# rownames(870): TFAP2B TFAP2D ... TBX18 TBX22
# rowData names(0):
# colnames(6): EXP-00776-P1_BMC05967-001 EXP-00776-P1_SP05965-01 ...
#   EXP-00776-P1_SP06133-01 EXP-00776-P1_SP06134-01
# colData names(5): Sample pool_id chip_id batch_id PassQC

# %%
hist(assays(z)[[1]][1,], breaks=50)
# Out:
# Plot with title “Histogram of assays(z)[[1]][1, ]”

# %%
assays(d)[[1]]
# Out:
#           EXP-00776-P1_BMC05967-001 EXP-00776-P1_SP05965-01
# TFAP2B     3.558234e-03              0.0043273840
# TFAP2D    -1.034262e-03              0.0014728401
# TFAP2C     3.257404e-03              0.0009992317
# TFAP2E    -4.309374e-05             -0.0031637057
# TFAP2A     7.474053e-04              0.0023202900
# ARID3A    -5.069395e-03              0.0056319994
# ARID5B    -7.874266e-03             -0.0116020815
# ARID3B     4.794471e-03              0.0155329511
# ARID5A     3.789626e-03              0.0093460745
# ARID3C    -5.623835e-03              0.0038290471
# ARID2      1.205508e-02              0.0042795426
# HMGA1     -8.463239e-03              0.0021906281
# HMGA2     -1.434813e-03              0.0107690734
# MAX        1.428840e-02              0.0165245355
# MLXIPL     1.541149e-02              0.0211350651
# ARNTL2     1.578325e-02              0.0194125398
# AHRR      -3.835286e-03             -0.0022311933
# TFE3       1.629896e-02              0.0207199566
# ...

# %%
z <- chrom$Z_Score

# %%
z
# Out:
# class: SummarizedExperiment
# dim: 870 6
# metadata(2): summarizedData History
# assays(5): ASC4 ASC1 ASC3 ASC5 ASC2
# rownames(870): TFAP2B TFAP2D ... TBX18 TBX22
# rowData names(0):
# colnames(6): EXP-00776-P1_BMC05967-001 EXP-00776-P1_SP05965-01 ...
#   EXP-00776-P1_SP06133-01 EXP-00776-P1_SP06134-01
# colData names(5): Sample pool_id chip_id batch_id PassQC

# %%
summary(assays(z)[[1]][1,])
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -0.5557  1.1725  1.8550  1.5814  2.0824  3.2306

# %%
assays(z)[[1]]['RUNX1', ]
# Out:
# EXP-00776-P1_BMC05967-001   EXP-00776-P1_SP05965-01   EXP-00776-P1_SP05966-01
#                 -10.48502                 -12.22973                 -16.85183
#   EXP-00776-P1_SP06132-01   EXP-00776-P1_SP06133-01   EXP-00776-P1_SP06134-01
#                 -10.07679                 -23.55910                 -11.85960

# %%
hist(c(assays(z)[[1]]['RUNX1', ], assays(z)[[2]]['RUNX1', ], assays(z)[[3]]['RUNX1', ], assays(z)[[4]]['RUNX1', ], assays(z)[[5]]['RUNX1', ]) )
# Out:
# Plot with title “Histogram of c(assays(z)[[1]]["RUNX1", ], assays(z)[[2]]["RUNX1", ], assays(z)[[3]]["RUNX1", ], assays(z)[[4]]["RUNX1", ], assays(z)[[5]]["RUNX1", ])”

# %%
c(assays(z)[[1]], assays(z)[[2]]['RUNX1', ], assays(z)[[3]]['RUNX1', ], assays(z)[[4]]['RUNX1', ], assays(z)[[5]]['RUNX1', ])
# Out:
#
#               2.100285562              -1.181759026               2.798378587
#
#              -0.022471231               0.473644112              -3.691718346
#
#              -1.801443808               1.739645427               1.169084586
#
#              -2.291839176               3.873076738              -4.671277012
#
#              -0.329599410               6.746274128               5.106433611
#
#               7.148589103              -1.777160447               7.287822498
#
#               3.192674695               4.706415909               1.894714128
#
#               3.175151241               8.081597368               0.652917450
#
#              -0.087763024               8.732683151               7.957783497
#
#              -1.777160447               5.589697033               1.161139286
#
#               1.857670568              10.416552851              -0.619999656
#
#              -0.920730981               6.107246671               5.587253869
#
# ...

# %%
hist(rbind(assays(z)[[1]], assays(z)[[2]]))
# Out:
# Plot with title “Histogram of rbind(assays(z)[[1]], assays(z)[[2]])”

# %%
df <- rbind(assays(z)[[1]], assays(z)[[2]], assays(z)[[3]], assays(z)[[4]], assays(z)[[5]])

# %%
collapsed <- data.frame(value = unlist(df, use.names = FALSE))

# %%
summary(stack(df)$value)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.     NA's
# -47.8759  -1.5789   0.2876   0.4376   2.2609  86.2524      870

# %%
hist(rbind(assays(z)[[1]], assays(z)[[2]], assays(z)[[3]], assays(z)[[4]], assays(z)[[5]]), breaks=50)
# Out:
# Plot with title “Histogram of rbind(assays(z)[[1]], assays(z)[[2]], assays(z)[[3]], assays(z)[[4]], assays(z)[[5]])”

# %%
summary(rbind(assays(z)[[1]], assays(z)[[2]], assays(z)[[3]], assays(z)[[4]], assays(z)[[5]]))
# Out:
#  EXP-00776-P1_BMC05967-001 EXP-00776-P1_SP05965-01 EXP-00776-P1_SP05966-01
#  Min.   :-26.0149          Min.   :-34.5010        Min.   :-31.6729
#  1st Qu.: -1.4736          1st Qu.: -1.5982        1st Qu.: -1.9028
#  Median :  0.3725          Median :  0.2368        Median : -0.1805
#  Mean   :  0.9502          Mean   :  0.4651        Mean   : -0.2932
#  3rd Qu.:  2.4181          3rd Qu.:  2.2981        3rd Qu.:  1.6566
#  Max.   : 86.2524          Max.   : 24.6970        Max.   : 18.0199
#
#  EXP-00776-P1_SP06132-01 EXP-00776-P1_SP06133-01 EXP-00776-P1_SP06134-01
#  Min.   :-41.1310        Min.   :-47.8759        Min.   :-26.3503
#  1st Qu.: -1.4530        1st Qu.: -1.8731        1st Qu.: -0.7262
#  Median :  0.5564        Median : -0.2314        Median :  1.1526
#  Mean   :  0.5964        Mean   : -0.1901        Mean   :  1.2622
#  3rd Qu.:  2.5316        3rd Qu.:  1.8170        3rd Qu.:  2.6389
#  Max.   : 22.6693        Max.   : 26.9512        Max.   : 55.5041
# ...

# %%
summary(c(assays(z)[[1]]['RUNX1', ], assays(z)[[2]]['RUNX1', ], assays(z)[[3]]['RUNX1', ], assays(z)[[4]]['RUNX1', ], assays(z)[[5]]['RUNX1', ]))
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
# -23.559 -11.860  -6.276  -3.106   7.029  21.174       1

# %%
means_list <- lapply(assayNames(z), function(ct) {
  means <- rowMedians(assays(z)[[ct]], na.rm = TRUE)
  data.frame(motif = names(means), mean_zscore = means, cell_type = ct)
})
means_df <- do.call(rbind, means_list)
# Out:
# Error in rowMedian(assays(z)[[ct]], na.rm = TRUE): could not find function "rowMedian"
# Traceback:
#
# 1. lapply(assayNames(z), function(ct) {
#  .     means <- rowMedian(assays(z)[[ct]], na.rm = TRUE)
#  .     data.frame(motif = names(means), mean_zscore = means, cell_type = ct)
#  . })
# 2. FUN(X[[i]], ...)
# 3. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "could not find function \"rowMedian\"", base::quote(rowMedian(assays(z)[[ct]],
#  .     na.rm = TRUE)))

# %%
means_df
# Out:
#            motif     mean_zscore  cell_type
# TFAP2B     TFAP2B     1.5813690   ASC4
# TFAP2D     TFAP2D     0.4080013   ASC4
# TFAP2C     TFAP2C     1.3460647   ASC4
# TFAP2E     TFAP2E    -0.8793661   ASC4
# TFAP2A     TFAP2A     0.1600095   ASC4
# ARID3A     ARID3A     3.0934033   ASC4
# ARID5B     ARID5B    -2.4915944   ASC4
# ARID3B     ARID3B     4.3396477   ASC4
# ARID5A     ARID5A     2.5530971   ASC4
# ARID3C     ARID3C     0.8124732   ASC4
# ARID2      ARID2      2.0226654   ASC4
# HMGA1      HMGA1     -1.1155720   ASC4
# HMGA2      HMGA2      2.5610812   ASC4
# MAX        MAX        6.4072363   ASC4
# MLXIPL     MLXIPL     5.3229778   ASC4
# ARNTL2     ARNTL2     6.8285150   ASC4
# AHRR       AHRR      -0.8301570   ASC4
# TFE3       TFE3       6.3616871   ASC4
# HES2       HES2       2.7199754   ASC4
# MNT        MNT        3.7281770   ASC4
# TCF3       TCF3      -3.1119626   ASC4
# SREBF1     SREBF1     0.9485025   ASC4
# TFAP4      TFAP4      0.4576709   ASC4
# ...

# %%
summary(means_df$mean_zscore)
summary(merged_df$mean_zscore)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -33.7884  -1.1403   0.2318   0.3852   1.9725  29.3499
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -33.7884  -6.5322   0.1290   0.9576   9.8180  29.3499

# %%
summary(means_df$mean_zscore)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -33.7884  -1.1403   0.2318   0.3852   1.9725  29.3499

# %%
# means_df <- means_df %>% filter(motif %in% unique(filtered_motifs$motif))

# %%
merged_df <- merge(filtered_motifs, means_df, by = c("motif", "cell_type"), all.x = TRUE)

# %%
dim(merged_df)
# Out:
# [1] 335  15

# %%
summary(merged_df$mean_zscore)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -33.7884  -6.5322   0.1290   0.9576   9.8180  29.3499

# %%
merged_df <- merge(filtered_motifs, means_df, by = c("motif", "cell_type"), all.x = TRUE)

# %%
means_df
# Out:
#            motif     mean_zscore  cell_type
# TFAP2B     TFAP2B     1.5813690   ASC4
# TFAP2D     TFAP2D     0.4080013   ASC4
# TFAP2C     TFAP2C     1.3460647   ASC4
# TFAP2E     TFAP2E    -0.8793661   ASC4
# TFAP2A     TFAP2A     0.1600095   ASC4
# ARID3A     ARID3A     3.0934033   ASC4
# ARID5B     ARID5B    -2.4915944   ASC4
# ARID3B     ARID3B     4.3396477   ASC4
# ARID5A     ARID5A     2.5530971   ASC4
# ARID3C     ARID3C     0.8124732   ASC4
# ARID2      ARID2      2.0226654   ASC4
# HMGA1      HMGA1     -1.1155720   ASC4
# HMGA2      HMGA2      2.5610812   ASC4
# MAX        MAX        6.4072363   ASC4
# MLXIPL     MLXIPL     5.3229778   ASC4
# ARNTL2     ARNTL2     6.8285150   ASC4
# AHRR       AHRR      -0.8301570   ASC4
# TFE3       TFE3       6.3616871   ASC4
# HES2       HES2       2.7199754   ASC4
# MNT        MNT        3.7281770   ASC4
# TCF3       TCF3      -3.1119626   ASC4
# SREBF1     SREBF1     0.9485025   ASC4
# TFAP4      TFAP4      0.4576709   ASC4
# ...

# %%
summary(means_df$mean_zscore)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -33.7884  -1.1403   0.2318   0.3852   1.9725  29.3499

# %%
merged_df
# Out:
#     motif  cell_type X    contrast    estimate    SE        df t.ratio
# 1   BACH1  ASC1       646 ASC1 effect -16.4077439 6.7185042 19 -2.442172
# 2   BACH1  ASC2       647 ASC2 effect -34.4575741 6.1713402 19 -5.583483
# 3   BACH1  ASC3       648 ASC3 effect   9.5772549 6.1713402 19  1.551892
# 4   BACH1  ASC4       649 ASC4 effect  21.4378783 6.1713402 19  3.473780
# 5   BACH1  ASC5       650 ASC5 effect  19.8501848 6.1713402 19  3.216511
# 6   BACH2  ASC1       561 ASC1 effect -15.3172117 4.9833138 19 -3.073700
# 7   BACH2  ASC2       562 ASC2 effect -27.0152555 4.5774661 19 -5.901793
# 8   BACH2  ASC3       563 ASC3 effect   7.8209236 4.5774661 19  1.708571
# 9   BACH2  ASC4       564 ASC4 effect  16.9408745 4.5774661 19  3.700928
# 10  BACH2  ASC5       565 ASC5 effect  17.5706691 4.5774661 19  3.838514
# 11  BCL11A ASC1       966 ASC1 effect   2.2098129 0.7294100 19  3.029590
# 12  BCL11A ASC2       967 ASC2 effect   5.3023160 0.6700058 19  7.913835
# ...

# %%
summary(merged_df$mean_zscore)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -33.7884  -6.5322   0.1290   0.9576   9.8180  29.3499

# %%
ggplot(merged_df, aes(cell_type, motif, 
                            fill = mean_zscore, 
                            size = mlogadjpval, 
                            color = p_adj < 0.1 & estimate > 0)) +
  geom_point(shape = 21, stroke = 1.2) +
  # geom_point(
  #   data = subset(filtered_motifs, is_top20),
  #   aes(shape="top 20"),
  #   shape = 21,
  #   stroke = 0.5,
  #   color = "black",
  #   fill = NA
  # ) +
  theme_bw() +
  scale_fill_gradientn(
      colours = c(inf[40], "white", inf[220]),
      values  = scales::rescale(c(-33.7884  , 0, 29.3499 )),
    ) + 
  scale_color_manual(values = c("white", "grey50")) +
  scale_shape_manual(
    name = "Top 20 motif",
    values = 21
  ) +
  scale_size_area(max_size = 5) +
  scale_x_discrete(limits = rev) +
  theme(
    panel.grid = element_blank(),
    axis.text.x = element_text(hjust = 1, angle = 45),
    legend.position = "bottom",
    legend.box = "horizontal",
    legend.key.width = unit(1, "cm"),
    legend.key.height = unit(1, "cm"),
    legend.text.align = 0.5
  ) +
  labs(
    x = NULL, y = NULL,
    size = "mlogadjpval",
    color = "p_adj < 0.1 & estimate > 0",
    fill = "average z-score"
  ) +
  guides(
      size = guide_legend(
        title.position = 'top',
        label.position = 'top',
        override.aes = list(
          shape = 21,
          fill  = "grey50",
          color = "grey50",
          stroke = 0
        )
      ), 
      color = guide_legend(
          title.position = 'top',
          label.position = 'top'
      ),
    ) +
  coord_flip()
# Out:
# plot without title

# %%
ggsave(paste0("bubble_motif_enrichment_zscore_no_top20.png"), width = 12, height = 3)

# %%
merged_df_full <- merge(anovaEnrichments, means_df, by = c("motif", "cell_type"), all.x = TRUE)

# %%
summary(means_df$mean_zscore)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -33.7884  -1.1403   0.2318   0.3852   1.9725  29.3499

# %%
write.csv(merged_df_full, 'anovaEnrichments_zscore.csv')

# %%
scaled_df <- merged_df %>%
  group_by(motif) %>%
  mutate(mean_zscore_scaled = scale(mean_zscore)[,1]) %>%
  ungroup()

# %%
summary(scaled_df$mean_zscore_scaled)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -1.5091 -0.7588  0.2034  0.0000  0.8034  1.6109

# %%
ggplot(scaled_df, aes(cell_type, motif, 
                            fill = mean_zscore_scaled, 
                            size = mlogadjpval, 
                            color = p_adj < 0.1 & estimate > 0)) +
  geom_point(shape = 21, stroke = 1.2) +
  # geom_point(
  #   data = subset(filtered_motifs, is_top20),
  #   aes(shape="top 20"),
  #   shape = 21,
  #   stroke = 0.5,
  #   color = "black",
  #   fill = NA
  # ) +
  theme_bw() +
  scale_fill_gradientn(
      colours = c(inf[40], "white", inf[220]),
      values  = scales::rescale(c(-0.7588    , 0, 0.8034   )),
    ) + 
  scale_color_manual(values = c("white", "grey50")) +
  scale_shape_manual(
    name = "Top 20 motif",
    values = 21
  ) +
  scale_size_area(max_size = 5) +
  scale_x_discrete(limits = rev) +
  theme(
    panel.grid = element_blank(),
    axis.text.x = element_text(hjust = 1, angle = 45),
    legend.position = "bottom",
    legend.box = "horizontal",
    legend.key.width = unit(1, "cm"),
    legend.key.height = unit(1, "cm"),
    legend.text.align = 0.5
  ) +
  labs(
    x = NULL, y = NULL,
    size = "mlogadjpval",
    color = "p_adj < 0.1 & estimate > 0",
    fill = "scaled average z-score"
  ) +
  guides(
      size = guide_legend(
        title.position = 'top',
        label.position = 'top',
        override.aes = list(
          shape = 21,
          fill  = "grey50",
          color = "grey50",
          stroke = 0
        )
      ), 
      color = guide_legend(
          title.position = 'top',
          label.position = 'top'
      ),
    ) +
  coord_flip()
# Out:
# plot without title

# %%
ggsave(paste0("bubble_motif_enrichment_zscore_scaled.png"), width = 12, height = 3)
